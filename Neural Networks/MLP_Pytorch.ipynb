# %% [markdown]
# ### Build a DNN for ECG Signal Classification (5 classes)  - Pytorch
# This is the implementation of an MLP for classifying the ECG signals. <br>

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as nnF
from torch.utils.data import DataLoader as torch_dataloader
from torch.utils.data import Dataset as torch_dataset
import torch.optim as optim

# %% [markdown]
# ## The Neural Network: MLP

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear1 = nn.Linear(in_features=187, out_features=512)
        self.linear2 = nn.Linear(512, 256)
        self.avg1 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.norm3 = nn.BatchNorm1d(256)
        self.linear3 = nn.Linear(256, 128)
        self.avg2 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.norm4 = nn.BatchNorm1d(128)
        self.linear4 = nn.Linear(128, 64)
        self.avg3 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.norm5 = nn.BatchNorm1d(64)
        self.linear5 = nn.Linear(64, 32)

        self.linear6 = nn.Linear(32, 5)

    def forward(self, x):
        x1 = nnF.relu(self.linear1(x))
        x2 = nnF.relu(self.linear2(x1))
        x3 = self.avg1(x1)
        x4 = x2 + x3

        x5 = self.norm3(x4)
        x6 = nnF.relu(self.linear3(x5))
        x7 = self.avg2(x4)
        x8 = x6 + x7

        x9 = self.norm4(x8)
        x10 = nnF.relu(self.linear4(x9))
        x11 = self.avg3(x8)
        x12 = x10 + x11
        
        x13 = self.norm5(x12)
        x14 = nnF.relu(self.linear5(x13))

        z=self.linear6(x14)

        return z

# %%
#debug your network here
#make sure it works for one single input sample
model=Net()
x=torch.rand(2,187) # (2,187) batch_size =2 if using BatchNorm
#x=torch.rand(10,1,187) if network is CNN
z=model(x)

# %%
def save_checkpoint(filename, model, optimizer, result, epoch):
    torch.save({'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'result':result},
               filename)
    print('saved:', filename)

# %%
def cal_accuracy(confusion):
    #input: confusion is the confusion matrix
    #output: acc is the standard classification accuracy
    M=confusion.copy().astype('float32')
    acc = M.diagonal().sum()/M.sum()    
    sens=np.zeros(M.shape[0])
    prec=np.zeros(M.shape[0]) 
    for n in range(0, M.shape[0]):
        TP=M[n,n]
        FN=np.sum(M[n,:])-TP
        FP=np.sum(M[:,n])-TP
        sens[n]=TP/(TP+FN)
        prec[n]=TP/(TP+FP)       
    return acc, sens, prec

# %% [markdown]
# ## The function to train the model

# %%
def train(model, device, optimizer, dataloader, epoch):    
    model.train()#set model to training mode
    loss_train=0
    acc_train =0 
    sample_count=0
    for batch_idx, (X, Y) in enumerate(dataloader):
        X, Y = X.to(device), Y.to(device)
        optimizer.zero_grad()#clear grad of each parameter
        Z = model(X)#forward pass
        loss = nnF.cross_entropy(Z, Y)
        loss.backward()#backward pass
        optimizer.step()#update parameters
        loss_train+=loss.item()
        #do not need softmax
        Yp = Z.data.max(dim=1)[1]  # get the index of the max               
        acc_train+= torch.sum(Yp==Y).item()
        sample_count+=X.size(0)
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{:.0f}%]\tLoss: {:.6f}'.format(
                    epoch, 100. * batch_idx / len(dataloader), loss.item()))
    loss_train/=len(dataloader)
    #due to upsampling, len(dataloader.dataset) != sample_count
    #acc_train/=len(dataloader.dataset) 
    acc_train/=sample_count    
    return loss_train, acc_train

# %% [markdown]
# ## The Function to test the model

# %%
def test(model, device, dataloader):
    model.eval()#set model to evaluation mode
    acc_test =0
    confusion=np.zeros((5,5))
    with torch.no_grad(): # tell Pytorch not to build graph in the with section
        for batch_idx, (X, Y) in enumerate(dataloader):
            X, Y = X.to(device), Y.to(device)
            Z = model(X)#forward pass
            #do not need softmax
            Yp = Z.data.max(dim=1)[1]  # get the index of the max 
            acc_test+= torch.sum(Yp==Y).item()
            for i in range(0, 5):
                for j in range(0, 5):
                    confusion[i,j]+=torch.sum((Y==i)&(Yp==j)).item()
    acc, sens, prec=cal_accuracy(confusion)
    return acc, (confusion, sens, prec)

# %% [markdown]
# ## Load data and create dataloaders

# %%
class MyDataset(torch_dataset):
    def __init__(self, X, Y):
        self.X=X
        self.Y=Y
    def __len__(self):
        #return the number of data points
        return self.X.shape[0]
    def __getitem__(self, idx):        
        #we can use DatasetName[idx] to get a data point (x,y) with index idx
        x=torch.tensor(self.X[idx], dtype=torch.float32)
        y=torch.tensor(self.Y[idx], dtype=torch.int64)
        #x=x.reshape(1,-1) if network is CNN
        return x, y

# %%
import pandas as pd
X=pd.read_csv('ECG_dataX.csv')
Y=pd.read_csv('ECG_dataY.csv')

# %%
#convert dataframe to numpy array
X=X.values
X.shape
# Out:
# (3841, 187)

# %%
#convert dataframe to numpy array
Y=Y.values
Y.shape
# Out:
# (3841, 1)

# %%
#reshape Y into a 1D array
Y=Y.reshape(-1)
Y.shape
# Out:
# (3841,)

# %%
plt.hist(Y)
# Out:
# (array([800.,   0., 800.,   0.,   0., 800.,   0., 641.,   0., 800.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
fs=125  # sampling frequency
Ts=1/fs # sampling interval
N=187 # the number of timepoints
Duration=N*Ts # duration of a signal
t=np.linspace(0, Duration-Ts, N) # array of timepoints
fig, ax = plt.subplots(5,1,constrained_layout=True, figsize=(10,10))
for c in range(0, 5):   
    for n in range(0, 3):
        idx=np.random.randint(0,10)
        ax[c].plot(t, X[Y==c][idx])        
        ax[c].set_xlabel('time t [seconds]', fontsize=16)
        ax[c].set_ylabel('amplitude', fontsize=16)
    ax[c].set_title('class '+str(c), fontsize=16)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=0)

# %%
dataset_train=MyDataset(X_train, Y_train)
dataset_val=MyDataset(X_val, Y_val)
dataset_test=MyDataset(X_test, Y_test)

# %%
loader_train = torch_dataloader(dataset_train, batch_size=128, shuffle=True, num_workers=0)
loader_val = torch_dataloader(dataset_val, batch_size=128, shuffle=False, num_workers=0) 
loader_test = torch_dataloader(dataset_test, batch_size=128, shuffle=False, num_workers=0)

# %% [markdown]
# ## Create a model, and start the traning-validation-testing process

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model=Net()
model.to(device)
x = torch.cat((dataset_train[0][0], dataset_train[1][0]))
print(x.shape)
x=x.view(2,187).to(device) #change it to x=x.view(1,1,187).to(device) for CNN

z=model(x)
# Out:
# torch.Size([374])

# %%
y_hat=nnF.softmax(z, dim=1)
y_hat
# Out:
# tensor([[0.1650, 0.2369, 0.1366, 0.2257, 0.2358],
#         [0.2094, 0.1678, 0.1635, 0.2659, 0.1934]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# use stochastic gradient descent as the optimization method

# %%
optimizer = optim.Adamax(model.parameters(), lr=0.001, weight_decay=1e-4)

# %%
loss_train_list=[]
acc_train_list=[]
acc_val_list=[]
epoch_save=-1

# %% [markdown]
# train/val/test over many epochs

# %%
for epoch in range(epoch_save+1, 100): #change 100 to a larger number if necessary
    #-------- training --------------------------------
    loss_train, acc_train =train(model, device, optimizer, loader_train, epoch)    
    loss_train_list.append(loss_train)
    acc_train_list.append(acc_train)
    print('epoch', epoch, 'training loss:', loss_train, 'acc:', acc_train)
    #-------- validation --------------------------------
    acc_val, other_val = test(model, device, loader_val)
    acc_val_list.append(acc_val)
    print('epoch', epoch, 'validation acc:', acc_val)
    #--------save model-------------------------
    result = (loss_train_list, acc_train_list, 
              acc_val_list, other_val)
    save_checkpoint('ECG_MLP_Pytorch_epoch'+str(epoch)+'.pt', model, optimizer, result, epoch)
    epoch_save=epoch
# Out:
# Train Epoch: 0 [0%]	Loss: 1.612662
# epoch 0 training loss: 1.1934976957061074 acc: 0.6353111432706223
# epoch 0 validation acc: 0.49675325
# saved: ECG_MLP_Pytorch_epoch0.pt
# Train Epoch: 1 [0%]	Loss: 0.875939
# <ipython-input-45-dfed762f0642>:13: RuntimeWarning: invalid value encountered in float_scalars
#   prec[n]=TP/(TP+FP)
# epoch 1 training loss: 0.8450951792977073 acc: 0.7749638205499276
# epoch 1 validation acc: 0.71428573
# saved: ECG_MLP_Pytorch_epoch1.pt
# Train Epoch: 2 [0%]	Loss: 0.697385
# epoch 2 training loss: 0.6354925334453583 acc: 0.8201881331403763
# epoch 2 validation acc: 0.7922078
# saved: ECG_MLP_Pytorch_epoch2.pt
# Train Epoch: 3 [0%]	Loss: 0.507193
# epoch 3 training loss: 0.4947012662887573 acc: 0.8531114327062229
# epoch 3 validation acc: 0.8246753
# saved: ECG_MLP_Pytorch_epoch3.pt
# Train Epoch: 4 [0%]	Loss: 0.459642
# epoch 4 training loss: 0.4119921191172166 acc: 0.8795224312590448
# epoch 4 validation acc: 0.8279221
# saved: ECG_MLP_Pytorch_epoch4.pt
# Train Epoch: 5 [0%]	Loss: 0.396089
# epoch 5 training loss: 0.34172398258339276 acc: 0.8965267727930536
# epoch 5 validation acc: 0.84090906
# saved: ECG_MLP_Pytorch_epoch5.pt
# Train Epoch: 6 [0%]	Loss: 0.372424
# epoch 6 training loss: 0.28101983869617636 acc: 0.9182344428364689
# epoch 6 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch6.pt
# Train Epoch: 7 [0%]	Loss: 0.224872
# epoch 7 training loss: 0.2463515583764423 acc: 0.9243849493487699
# epoch 7 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch7.pt
# Train Epoch: 8 [0%]	Loss: 0.208504
# epoch 8 training loss: 0.20857727866281162 acc: 0.9403039073806078
# epoch 8 validation acc: 0.8603896
# saved: ECG_MLP_Pytorch_epoch8.pt
# Train Epoch: 9 [0%]	Loss: 0.138814
# epoch 9 training loss: 0.18700287626548248 acc: 0.9424746743849494
# epoch 9 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch9.pt
# Train Epoch: 10 [0%]	Loss: 0.108368
# epoch 10 training loss: 0.15038638629696585 acc: 0.9540520984081042
# epoch 10 validation acc: 0.8733766
# saved: ECG_MLP_Pytorch_epoch10.pt
# Train Epoch: 11 [0%]	Loss: 0.106463
# epoch 11 training loss: 0.13513311100277034 acc: 0.9576700434153401
# epoch 11 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch11.pt
# Train Epoch: 12 [0%]	Loss: 0.084458
# epoch 12 training loss: 0.12570380385626445 acc: 0.9620115774240231
# epoch 12 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch12.pt
# Train Epoch: 13 [0%]	Loss: 0.085632
# epoch 13 training loss: 0.10959702425382355 acc: 0.9678002894356006
# epoch 13 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch13.pt
# Train Epoch: 14 [0%]	Loss: 0.089413
# epoch 14 training loss: 0.09539941224184903 acc: 0.9725036179450073
# epoch 14 validation acc: 0.8603896
# saved: ECG_MLP_Pytorch_epoch14.pt
# Train Epoch: 15 [0%]	Loss: 0.085238
# epoch 15 training loss: 0.08059771900827234 acc: 0.9793777134587555
# epoch 15 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch15.pt
# Train Epoch: 16 [0%]	Loss: 0.032405
# epoch 16 training loss: 0.06818212145431475 acc: 0.9801013024602026
# epoch 16 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch16.pt
# Train Epoch: 17 [0%]	Loss: 0.070876
# epoch 17 training loss: 0.062359653413295746 acc: 0.9869753979739508
# epoch 17 validation acc: 0.8733766
# saved: ECG_MLP_Pytorch_epoch17.pt
# Train Epoch: 18 [0%]	Loss: 0.093592
# epoch 18 training loss: 0.055175815454938194 acc: 0.9876989869753979
# epoch 18 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch18.pt
# Train Epoch: 19 [0%]	Loss: 0.048136
# epoch 19 training loss: 0.061694557863202965 acc: 0.9844428364688856
# epoch 19 validation acc: 0.8603896
# saved: ECG_MLP_Pytorch_epo
validation acc: 0.8701299
# saved: ECG_MLP_Pytorch_epoch86.pt
# Train Epoch: 87 [0%]	Loss: 0.006511
# epoch 87 training loss: 0.01103788244125264 acc: 0.9963820549927641
# epoch 87 validation acc: 0.85714287
# saved: ECG_MLP_Pytorch_epoch87.pt
# Train Epoch: 88 [0%]	Loss: 0.000836
# epoch 88 training loss: 0.010022627634250304 acc: 0.9963820549927641
# epoch 88 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch88.pt
# Train Epoch: 89 [0%]	Loss: 0.025047
# epoch 89 training loss: 0.007264463876543397 acc: 0.9974674384949349
# epoch 89 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch89.pt
# Train Epoch: 90 [0%]	Loss: 0.001906
# epoch 90 training loss: 0.004349321021105756 acc: 0.9989146164978292
# epoch 90 validation acc: 0.8701299
# saved: ECG_MLP_Pytorch_epoch90.pt
# Train Epoch: 91 [0%]	Loss: 0.009946
# epoch 91 training loss: 0.011090159707237035 acc: 0.9978292329956585
# epoch 91 validation acc: 0.8733766
# saved: ECG_MLP_Pytorch_epoch91.pt
# Train Epoch: 92 [0%]	Loss: 0.001008
# epoch 92 training loss: 0.006063249411950396 acc: 0.998191027496382
# epoch 92 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch92.pt
# Train Epoch: 93 [0%]	Loss: 0.003272
# epoch 93 training loss: 0.012315141542454843 acc: 0.9971056439942113
# epoch 93 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch93.pt
# Train Epoch: 94 [0%]	Loss: 0.014184
# epoch 94 training loss: 0.007252802828919481 acc: 0.9989146164978292
# epoch 94 validation acc: 0.8701299
# saved: ECG_MLP_Pytorch_epoch94.pt
# Train Epoch: 95 [0%]	Loss: 0.001978
# epoch 95 training loss: 0.007006410009291192 acc: 0.9978292329956585
# epoch 95 validation acc: 0.8733766
# saved: ECG_MLP_Pytorch_epoch95.pt
# Train Epoch: 96 [0%]	Loss: 0.007129
# epoch 96 training loss: 0.02155229299255139 acc: 0.993849493487699
# epoch 96 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch96.pt
# Train Epoch: 97 [0%]	Loss: 0.006826
# epoch 97 training loss: 0.02557285541446287 acc: 0.993849493487699
# epoch 97 validation acc: 0.85714287
# saved: ECG_MLP_Pytorch_epoch97.pt
# Train Epoch: 98 [0%]	Loss: 0.001680
# epoch 98 training loss: 0.022118236758449875 acc: 0.9924023154848046
# epoch 98 validation acc: 0.8733766
# saved: ECG_MLP_Pytorch_epoch98.pt
# Train Epoch: 99 [0%]	Loss: 0.020837
# epoch 99 training loss: 0.009622171325397423 acc: 0.9974674384949349
# epoch 99 validation acc: 0.8733766
# saved: ECG_MLP_Pytorch_epoch99.pt

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))
ax[0].set_title('loss v.s. epoch',fontsize=16)
ax[0].plot(loss_train_list, '-b', label='training loss')
ax[0].set_xlabel('epoch',fontsize=16)
ax[0].legend(fontsize=16)
ax[0].grid(True)
ax[1].set_title('accuracy v.s. epoch',fontsize=16)
ax[1].plot(acc_train_list, '-b', label='training accuracy')
ax[1].plot(acc_val_list, '-g', label='validation accuracy')
ax[1].set_xlabel('epoch',fontsize=16)
ax[1].legend(fontsize=16)
ax[1].grid(True)

# %% [markdown]
# load the best model

# %%
best_epoch=np.argmax(acc_val_list)
best_epoch
# Out:
# 45

# %%
checkpoint=torch.load('ECG_MLP_Pytorch_epoch'+str(best_epoch)+'.pt')
model=Net()
model.load_state_dict(checkpoint['model_state_dict'])
model.to(device);
model.eval();

# %%
acc, (confusion, sens, prec) = test(model, device, loader_test)
print('Accuracy (average)', acc)
print('Sensitivity', sens)
print('Precision', prec)
print('Confusion \n', confusion)
# Out:
# Accuracy (average) 0.8972692
# Sensitivity [0.80681819 0.90259743 0.91095889 0.95901638 0.92982459]
# Precision [0.86060607 0.85802472 0.91095889 0.87313432 0.98148149]
# Confusion
#  [[142.  17.   8.   7.   2.]
#  [ 12. 139.   1.   1.   1.]
#  [  4.   2. 133.   7.   0.]
#  [  4.   0.   1. 117.   0.]
#  [  3.   4.   3.   2. 159.]]
